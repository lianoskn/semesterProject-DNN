# %%
# %matplotlib inline

import os
from scipy import misc
import numpy as np
datapath = 'train/'
dirpath = "/home/lianos91/Desktop/training_patches/train_patches_128_64_rich/"
import matplotlib.pyplot as plt
#from skimage import data, io, filters

# %%
fileslist = next(os.walk(dirpath+datapath))[2]
dir_size = len(fileslist)

# %%
mean_img = np.zeros([64,64,3])

# %%
i=0
file = fileslist[i]
img = misc.imread(dirpath+datapath+file)        
img = img.astype(np.float16)

# %%
for i in range(0,dir_size):
    file = fileslist[i]
    img = misc.imread(dirpath+datapath+file)        
    img = img.astype(np.float16)/255.
    mean_img = mean_img + img
    
import scipy.misc
scipy.misc.imsave('mean_img_rich.png', mean_img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-9e2de087628e> in <module>()
#       6
#       7
# ----> 8 result = Image.fromarray(((mean_img/dir_size)*255.).astype(numpy.uint8))
#       9 result.save('mean_img_rich.png')
#
# NameError: name 'Image' is not defined

# %%
#flip TICK
p = 0.4
if p < 0.45:
    a = np.copy(img)
    for i in range(64):
        a[:,i] = img[:,-i-1]
        img2 = a

# %%
imgplot=plt.imshow(mean_img[:,:,0])

# %%
imgplot=plt.imshow(img)

# %%
q = 0
a = img[q: 64-(4-q), q: 64-(4-q)]
b=np.pad(a,(2,2),'edge')
plt.imshow(b)

# %%
np.shape(a)
# Out:
# (60, 60)
